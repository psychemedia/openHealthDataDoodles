# %% [markdown]
# # NHS Written Complaints Against GPs and Dental Practices - Annual Reports
#
# The parent data collection is the [General Practice (including Dental) Complaints Collection (KO41b)](http://digital.nhs.uk/datacollections/ko41b).
#
# The data finder query is for national statisics on [Patient experience / Complaints](http://digital.nhs.uk/searchcatalogue?topics=1/Patient%20experience/Complaints&sort=Relevance&size=10&page=1#top). This query also returns links to experimental quarterly reports.
#
# The data is also registered with data.gov.uk at https://data.gov.uk/dataset/data_on_written_complaints_in_the_nhs
#
# NOTE: *The column names used are not necessarily consistent year on year so some cleaning may be required to get the report generator to work correctly.*

# %% [markdown]
# ## Setup
#
# Import necessary libraries and supporting administrative data.

# %%
import pandas as pd

# %% [markdown]
# We can import GP administrative data from the `nhsadmin.sqlite` database as generated in the [NHS and GP Administrative Data.ipynb](NHS%20and%20GP%20Administrative%20Data.ipynb) notebook.

# %%
import sqlite3
con = sqlite3.connect("nhsadmin.sqlite")

gp = pd.read_sql_query('SELECT * from epraccur', con)
gp.head()
# Out:
#   Organisation Code                        Name National Grouping  \
# 0            A81001         THE DENSHAM SURGERY               Y54
# 1            A81002  QUEENS PARK MEDICAL CENTRE               Y54
# 2            A81003   VICTORIA MEDICAL PRACTICE               Y54
# 3            A81004      WOODLANDS ROAD SURGERY               Y54
# 4            A81005          SPRINGWOOD SURGERY               Y54
#
#   High Level Health Geography           Address Line 1 Address Line 2  \
# 0                         Q74        THE HEALTH CENTRE  LAWSON STREET
# 1                         Q74  QUEENS PARK MEDICAL CTR  FARRER STREET
# 2                         Q74        THE HEALTH CENTRE  VICTORIA ROAD
# 3                         Q74         6 WOODLANDS ROAD           None
# 4                         Q74       SPRINGWOOD SURGERY   RECTORY LANE
#
#      Address Line 3 Address Line 4 Address Line 5  Postcode  \
# 0  STOCKTON-ON-TEES      CLEVELAND           None  TS18 1HU
# 1  STOCKTON ON TEES      CLEVELAND           None  TS18 2AW
# 2        HARTLEPOOL      CLEVELAND           None  TS26 8DB
# 3     MIDDLESBROUGH      CLEVELAND           None   TS1 3BE
# 4       GUISBOROUGH           None           None  TS14 7DJ
#
#           ...         Close Date Status Code Organisation Sub-Type code  \
# 0         ...               None           A                          B
# 1         ...               None           A                          B
# 2         ...               None           A                          B
# 3         ...               None           A                          B
# 4         ...               None           A                          B
#
#   Commissioner Join Provider/Purchaser Date Left Provider/Purchaser Date  \
# 0          00K          2013-04-01 00:00:00                         None
# 1          00K          2013-04-01 00:00:00                         None
# 2          00K          2013-04-01 00:00:00                         None
# 3          00M          2013-04-01 00:00:00                         None
# 4          00M          2013-04-01 00:00:00                         None
#
#   Contact Telephone Number Amended Record Indicator  Provider/Purchaser  \
# 0             01642 672351                        0                 00K
# 1             01642 679681                        0                 00K
# 2             01429 272945                        0                 00K
# 3             01642 247982                        0                 00M
# 4             01287 619611                        0                 00M
#
#   Prescribing Setting
# 0                   4
# 1                   4
# 2                   4
# 3                   4
# 4                   4
#
# [5 rows x 21 columns]

# %%
dentists=pd.read_sql_query('SELECT * from egdpprac', con)
dentists.head()
# Out:
#   Organisation Code                           Name National Grouping  \
# 0            V00002                 DENTAL SURGERY               Y52
# 1            V00003  CRABTREE ROAD DENTAL PRACTICE               Y57
# 2            V00004                 DENTAL SURGERY               Y57
# 3            V00005                 DENTAL SURGERY               Y57
# 4            V00006                 DENTAL SURGERY               Y57
#
#   High Level Health Geography                 Address Line 1  \
# 0                         Q37                 DENTAL SURGERY
# 1                         Q81  CRABTREE ROAD DENTAL PRACTICE
# 2                         Q81                 DENTAL SURGERY
# 3                         Q81                 DENTAL SURGERY
# 4                         Q81                 DENTAL SURGERY
#
#       Address Line 2 Address Line 3 Address Line 4 Address Line 5  Postcode  \
# 0  22 MARTYRS AVENUE        CRAWLEY    WEST SUSSEX           None  RH11 7RZ
# 1   25 CRABTREE ROAD        CRAWLEY    WEST SUSSEX           None  RH11 7HL
# 2          WOODCROFT    BEPTON ROAD       MIDHURST    WEST SUSSEX  GU29 9HH
# 3     31 WICK STREET           WICK  LITTLEHAMPTON    WEST SUSSEX  BN17 7JJ
# 4   43 BUSTICLE LANE       SOMPTING        LANCING    WEST SUSSEX  BN15 0DJ
#
#              Open Date           Close Date Status Code  \
# 0  2008-04-01 00:00:00  2009-03-31 00:00:00           C
# 1  2006-04-01 00:00:00                 None           A
# 2  2006-04-01 00:00:00                 None           A
# 3  2006-04-01 00:00:00                 None           A
# 4  2006-04-01 00:00:00                 None           A
#
#   Organisation Sub-Type Code Parent Organisation Code     Join Parent Date  \
# 0                          D                      5P6  2008-04-01 00:00:00
# 1                          D                      14G  2015-04-01 00:00:00
# 2                          D                      14G  2015-04-01 00:00:00
# 3                          D                      14G  2015-04-01 00:00:00
# 4                          D                      14G  2015-04-01 00:00:00
#
#       Left Parent Date  Amended Record Indicator
# 0  2009-03-31 00:00:00                         0
# 1                 None                         0
# 2                 None                         0
# 3                 None                         0
# 4                 None                         0

# %%
#Create a function to grab a zip file from an online location and then grab a specified file from inside it
import requests, zipfile, StringIO
def zipgrabber(url):
    r = requests.get(url)
    z = zipfile.ZipFile(StringIO.StringIO(r.content))
    return z

def csvfileopener(z,k,metadata=False):
    f=None
    for n in z.namelist():
        if n.split('.')[-1]=='csv' and k in n: f=n
    if f is not None:
        df = pd.read_csv(z.open(f))
        df.dropna(how='all',axis=1,inplace=True)
        df=df[[c for c in df.columns if not c.startswith('Unnamed')]]
        if metadata:
            complaints_meta = get_metadata(z)
            cols=['::'.join(x) for x in zip(complaints_meta['Name'],complaints_meta['meta'])]
            df.columns=cols
        return df
    return pd.DataFrame()

# %%
def get_metadata(z):
    for n in z.namelist():
        if 'xls' in n and 'meta' in n: f=n
    xl=pd.ExcelFile(z.open(f))
    for n in xl.sheet_names:
        if 'KO41b' in n: sheetname=n
    complaints_meta=xl.parse(sheetname,header=None)
    complaints_meta.columns=['Name','typ','meta']
    complaints_meta = complaints_meta[complaints_meta['Name']!='Column']
    return complaints_meta

# %% [markdown]
# ## Complaints Data - 2015 / 16
#
# via: http://digital.nhs.uk/datacollections/ko41b
# specifically: http://digital.nhs.uk/searchcatalogue?productid=21728

# %%
url='http://www.digital.nhs.uk/catalogue/PUB21533/data-writ-comp-nhs-2015-2016-csv.zip'
zip_2015_16=zipgrabber(url)

complaints_2015_16=csvfileopener(zip_2015_16,'KO41a')
complaints_2015_16.head(3)
# Out:
#      Quarter OrganisationCode         OrganisationName SiteCode  \
# 0  201516 Q1            8EL02    Health First (UK) Ltd    8EL02
# 1  201516 Q1              AAW  Allied Healthcare Group      AAW
# 2  201516 Q1              NLO                   Vocare    NLO01
#
#                        SiteName  ComplaintsTotalBroughtForward  \
# 0         Health First (UK) Ltd                              0
# 1       ALLIED HEALTHCARE GROUP                              0
# 2  NORTHERN DOCTORS URGENT CARE                              0
#
#    ComplaintsTotalNew  ComplaintsTotalResolved  ComplaintsNumberUpheld  \
# 0                   0                        0                       0
# 1                  24                       21                       4
# 2                  27                       27                      12
#
#    ComplaintsNumberPartiallyUpheld            ...             \
# 0                                0            ...
# 1                                6            ...
# 2                                5            ...
#
#    ProfessionAmbulance  ProfessionSupportToClinicalStaff  \
# 0                    0                                 0
# 1                    0                                 4
# 2                    0                                 0
#
#    ProfessionNHSInfrastructureSupport  ProfessionOther  ProfessionTotal  \
# 0                                   0                0                0
# 1                                   0               10               24
# 2                                   0                0               27
#
#    NHSEnglandRegionCode                               NHSEnglandRegionName  \
# 0                   QZZ  Special Health Authorities and other statutory...
# 1                   QZZ  Special Health Authorities and other statutory...
# 2                   QZZ  Special Health Authorities and other statutory...
#
#    NHSEnglandRegionGeographyCode  \
# 0                            QZZ
# 1                            QZZ
# 2                            QZZ
#
#                        NHSEnglandRegionGeographyName          OrganisationType
# 0  Special Health Authorities and other statutory...                    Others
# 1  Special Health Authorities and other statutory...  Community Provider Trust
# 2  Special Health Authorities and other statutory...  Community Provider Trust
#
# [3 rows x 88 columns]

# %%
complaints_b_2015_16=csvfileopener(zip_2015_16,'KO41b',True)
complaints_b_2015_16.head(3)
# Out:
#   Year::Year of collection  \
# 0                  2015-16
# 1                  2015-16
# 2                  2015-16
#
#   Return::Organisation type (NHS England, GP, Dental) making return  \
# 0                                        NHS England
# 1                                        NHS England
# 2                                        NHS England
#
#   NHSERegionCode::NHS England Region Code  \
# 0                                     Y57
# 1                                     Y57
# 2                                     Y56
#
#   NHSERegionName::NHS England Region Name  \
# 0                        South of England
# 1                        South of England
# 2                                  London
#
#   NHSERegionGeographyCode::NHS England Region Geography Code  \
# 0                                                Q70
# 1                                                Q70
# 2                                                Q71
#
#   NHSERegionGeographyName::NHS England Region Geography Name  \
# 0                         NHS England South (Wessex)
# 1                         NHS England South (Wessex)
# 2                                 NHS England London
#
#   Practice_Code::Dental/GP Practice Code  Medical TOTAL::Complaints by area  \
# 0                                    Q70                                 95
# 1                                    Q70                                  0
# 2                                    Q71                                460
#
#    Dental TOTAL::Complaints by area  Practice admin TOTAL::Complaints by area  \
# 0                                 0                                         1
# 1                                54                                         0
# 2                                 0                                        76
#
#                           ...                          \
# 0                         ...
# 1                         ...
# 2                         ...
#
#    Practice admin UPHELD::Complaints upheld by area  \
# 0                                                 0
# 1                                                 0
# 2                                                27
#
#    Other UPHELD::Complaints upheld by area  \
# 0                                        0
# 1                                        0
# 2                                        0
#
#    Total UPHELD::Complaints upheld by area  \
# 0                                       64
# 1                                       29
# 2                                      185
#
#    Communications/Attitude SUBJECT UPHELD::Complaints upheld by subject  \
# 0                                                  9
# 1                                                  4
# 2                                                 48
#
#    Premises SUBJECT UPHELD::Complaints upheld by subject  \
# 0                                                  0
# 1                                                  0
# 2                                                  1
#
#    Practice/Surgery Management SUBJECT UPHELD::Complaints upheld by subject  \
# 0                                                 11
# 1                                                  5
# 2                                                 56
#
#    Practice admin SUBJECT UPHELD::Complaints upheld by subject  \
# 0                                                  1
# 1                                                  3
# 2                                                 21
#
#    Clinical SUBJECT UPHELD::Complaints upheld by subject  \
# 0                                                 42
# 1                                                 16
# 2                                                 59
#
#    Other SUBJECT UPHELD::Complaints upheld by subject  \
# 0                                                  1
# 1                                                  1
# 2                                                  0
#
#    Total SUBJECT UPHELD::Complaints upheld by subject
# 0                                                 64
# 1                                                 29
# 2                                                185
#
# [3 rows x 31 columns]

# %%
#join complaints parent codes
parentGP=gp[['Organisation Code','Commissioner']]
parentGP.columns=['Organisation Code','Parent Organisation Code']
parentDentist=dentists[['Organisation Code','Parent Organisation Code']]
codeparent=pd.concat([parentGP,parentDentist])
codeparent.head(3)
# Out:
#   Organisation Code Parent Organisation Code
# 0            A81001                      00K
# 1            A81002                      00K
# 2            A81003                      00K

# %%
iwcodes=codeparent[(codeparent['Parent Organisation Code']=='10L')]
complaints_iw=pd.merge(complaints_b,iwcodes, left_on='Practice_Code::Dental/GP Practice Code', right_on='Organisation Code')
gp[gp['Organisation Code'].isin(complaints_iw['Practice_Code::Dental/GP Practice Code'].tolist())].head()
# Out:
#      Organisation Code                       Name National Grouping  \
# 5255            J84003     VENTNOR MEDICAL CENTRE               Y57
# 5256            J84004  EAST COWES MEDICAL CENTRE               Y57
# 5257            J84005          ESPLANADE SURGERY               Y57
# 5258            J84007   ST.HELENS MEDICAL CENTRE               Y57
# 5259            J84008               ARGYLL HOUSE               Y57
#
#      High Level Health Geography             Address Line 1    Address Line 2  \
# 5255                         Q70     VENTNOR MEDICAL CENTRE   3 ALBERT STREET
# 5256                         Q70  EAST COWES MEDICAL CENTRE       CHURCH PATH
# 5257                         Q70      THE ESPLANADE SURGERY  19 THE ESPLANADE
# 5258                         Q70   ST.HELENS MEDICAL CENTRE  UPPER GREEN ROAD
# 5259                         Q70               ARGYLL HOUSE       WEST STREET
#
#      Address Line 3 Address Line 4 Address Line 5  Postcode  \
# 5255        VENTNOR  ISLE OF WIGHT           None  PO38 1EZ
# 5256     EAST COWES  ISLE OF WIGHT           None  PO32 6RP
# 5257           RYDE  ISLE OF WIGHT           None  PO33 2EH
# 5258      ST.HELENS  ISLE OF WIGHT           None  PO33 1UG
# 5259           RYDE  ISLE OF WIGHT           None  PO33 2QG
#
#              ...         Close Date Status Code Organisation Sub-Type code  \
# 5255         ...               None           A                          B
# 5256         ...               None           A                          B
# 5257         ...               None           A                          B
# 5258         ...               None           A                          B
# 5259         ...               None           A                          B
#
#      Commissioner Join Provider/Purchaser Date Left Provider/Purchaser Date  \
# 5255          10L          2013-04-01 00:00:00                         None
# 5256          10L          2013-04-01 00:00:00                         None
# 5257          10L          2013-04-01 00:00:00                         None
# 5258          10L          2013-04-01 00:00:00                         None
# 5259          10L          2013-04-01 00:00:00                         None
#
#      Contact Telephone Number Amended Record Indicator  Provider/Purchaser  \
# 5255             01983 857288                        0                 10L
# 5256             01983 284333                        0                 10L
# 5257             01983 618388                        0                 10L
# 5258             01983 871828                        0                 10L
# 5259             01983 562955                        0                 10L
#
#      Prescribing Setting
# 5255                   4
# 5256                   4
# 5257                   4
# 5258                   4
# 5259                   4
#
# [5 rows x 21 columns]

# %%
import re

def epracurrDetails(code):
    return gp[gp['Organisation Code']==code].to_dict(orient='records')[0]

def getAddress(d):
    c=[x for x in d.keys() if 'address line' in x.lower()]
    c.append('Postcode')
    return [d[x] for x in c if ((d[x] is not None) and not pd.isnull(d[x]))]  

def receivedUpheld(d,k):
    rxd=d[k]['received'] if 'received' in d[k] else 0
    upheld=d[k]['upheld'] if 'upheld' in d[k] else 0
    return rxd,upheld

def receivedUpheldArea(d,k,hack2014=False):
    if hack2014: return receivedUpheld(d,k)
    rxd=d[k]['Complaints by area'] if 'Complaints by area' in d[k] else 0
    upheld=d[k]['Complaints upheld by area'] if 'Complaints upheld by area' in d[k] else 0
    return rxd,upheld

def receivedUpheldSubject(d,k,hack2014=False):
    if hack2014: return receivedUpheld(d,k)
    rxd=d[k]['Complaints by subject'] if 'Complaints by subject' in d[k] else 0
    upheld=d[k]['Complaints upheld by subject'] if 'Complaints upheld by subject' in d[k] else 0
    return rxd,upheld

def complaintReport(item,hack2014=False):
    details=epracurrDetails(item['Practice_Code::Dental/GP Practice Code'])
    txt='\n---------------\n'
    txt=txt+'Complaint report for: {name} ({code})\n'.format(name=details['Name'],
                                                      code=item['Practice_Code::Dental/GP Practice Code'])
    txt=txt+'\nAddress: {addr}.'.format(addr=', '.join(getAddress(details)))
    if ((details['Contact Telephone Number'] is not None) and not pd.isnull(details['Contact Telephone Number'])):
        txt=txt+'\nTelephone: {tel}'.format(tel=details['Contact Telephone Number'])
    txt=txt+'\n'
    
    if hack2014:
        complaints_received={'Complaint by subject':{},'Complaint by area':{}}
        complaints_upheld={'Complaint by subject':{},'Complaint by area':{}}
    else:
        complaints_received={'Complaints by subject':{},'Complaints by area':{}}
        complaints_upheld={'Complaints upheld by subject':{},'Complaints upheld by area':{}}
    
    complaints_by_area={}
    complaints_by_subject={}
    for col in item.index.values:
        if 'complaint' in col.lower() and item[col]>0:
            
            if hack2014:
                k=col.replace('\n','').split('Total number of written complaints ')

                if k[0]=='': k[0]='Total'
                k[0]=k[0].strip()
                k[1]=k[1]

                if 'received' in k[1]:
                    complaints_received[k[1].split('::')[1]][k[0]]=int(item[col])   
                elif 'upheld' in k[1]:
                    complaints_upheld[k[1].split('::')[1]][k[0]]=int(item[col])

                if 'area' in k[1]:
                    if k[0] not in complaints_by_area: complaints_by_area[k[0]]={}
                    complaints_by_area[k[0]][k[1].split('::')[0]]=int(item[col])
                elif 'subject' in k[1]:
                    if k[0] not in complaints_by_subject: complaints_by_subject[k[0]]={}
                    complaints_by_subject[k[0]][k[1].split('::')[0]]=int(item[col])
            else:
                if 'TOTAL' in col:
                    k=re.compile(r' SUBJECT TOTAL| TOTAL').split(col)
                    k[1]=k[1].lstrip('::')
                    complaints_received[k[1]][k[0]]=int(item[col])   
                elif 'UPHELD' in col:
                    k=re.compile(r' SUBJECT UPHELD| UPHELD').split(col)
                    k[1]=k[1].lstrip('::')
                    complaints_upheld[k[1]][k[0]]=int(item[col])

                if 'area' in col:
                    if k[0] not in complaints_by_area: complaints_by_area[k[0]]={}
                    complaints_by_area[k[0]][k[1].split('::')[0]]=int(item[col])
                elif 'subject' in col:
                    if k[0] not in complaints_by_subject: complaints_by_subject[k[0]]={}
                    complaints_by_subject[k[0]][k[1].split('::')[0]]=int(item[col])
                
    txt=txt+'\n'

    if complaints_by_area!={}:
        rxd,upheld=receivedUpheldArea(complaints_by_area,"Total",hack2014)
        txt=txt+'Complaints by area ({} received, of which {} upheld):'.format(rxd,upheld)
        for complaint in complaints_by_area:
            if complaint=='Total': continue
            rxd,upheld=receivedUpheldArea(complaints_by_area,complaint,hack2014)
            txt=txt+'\n    - {}: {} received, of which {} upheld.'.format(complaint,rxd,upheld)
        txt=txt+'\n\n'
    else: txt=txt+'No complaints by area.\n' 
        
    if complaints_by_subject!={}:
        rxd,upheld=receivedUpheldSubject(complaints_by_subject,"Total",hack2014)
        txt=txt+'Complaints by subject ({} received, of which {} upheld):'.format(rxd,upheld)
        for complaint in complaints_by_subject:
            if complaint=='Total': continue
            rxd,upheld=receivedUpheldSubject(complaints_by_subject,complaint,hack2014)
            txt=txt+'\n    - {}: {} received, of which {} upheld.'.format(complaint,rxd,upheld)
    else: txt=txt+'No complaints by subject.\n\n'      
    #print(txt)
    #print('\n---------------\n')
    
    return txt

reports=complaints_iw.apply(lambda x: complaintReport(x), axis=1 )

print('''
National Statistics Data on Written Complaints in the NHS - 2015-16 [NS]
Publication date: September 15, 2016
http://www.digital.nhs.uk/catalogue/PUB21533
''')

for report in reports:
    print(report)
# Out:
# National Statistics Data on Written Complaints in the NHS - 2015-16 [NS]
# Publication date: September 15, 2016
# http://www.digital.nhs.uk/catalogue/PUB21533
#
#
# ---------------
# Complaint report for: ST.HELENS MEDICAL CENTRE (J84007)
#
# Address: ST.HELENS MEDICAL CENTRE, UPPER GREEN ROAD, ST.HELENS, ISLE OF WIGHT, PO33 1UG.
# Telephone: 01983 871828
#
# Complaints by area (14 received, of which 14 upheld):
#     - Practice admin: 5 received, of which 5 upheld.
#     - Medical: 9 received, of which 9 upheld.
#
# Complaints by subject (14 received, of which 14 upheld):
#     - Communications/Attitude: 5 received, of which 5 upheld.
#     - Practice/Surgery Management: 1 received, of which 1 upheld.
#     - Practice admin: 2 received, of which 2 upheld.
#     - Clinical: 6 received, of which 5 upheld.
#     - Other: 0 received, of which 1 upheld.
#
# ---------------
# Complaint report for: WEST WIGHT MEDICAL PRACTICE (J84019)
#
# Address: BROOKSIDE HEALTH CENTRE, QUEENS ROAD, FRESHWATER, ISLE OF WIGHT, PO40 9DT.
# Telephone: 01983 758998
#
# Complaints by area (7 received, of which 0 upheld):
#     - Other: 7 received, of which 0 upheld.
#
# Complaints by subject (7 received, of which 0 upheld):
#     - Practice admin: 2 received, of which 0 upheld.
#     - Communications/Attitude: 1 received, of which 0 upheld.
#     - Clinical: 2 received, of which 0 upheld.
#     - Practice/Surgery Management: 2 received, of which 0 upheld.
#
# ---------------
# Complaint report for: VENTNOR MEDICAL CENTRE (J84003)
#
# Address: VENTNOR MEDICAL CENTRE, 3 ALBERT STREET, VENTNOR, ISLE OF WIGHT, PO38 1EZ.
# Telephone: 01983 857288
#
# No complaints by area.
# No complaints by subject.
#
#
#
# ---------------
# Complaint report for: EAST COWES MEDICAL CENTRE (J84004)
#
# Address: EAST COWES MEDICAL CENTRE, CHURCH PATH, EAST COWES, ISLE OF WIGHT, PO32 6RP.
# Telephone: 01983 284333
#
# Complaints by area (6 received, of which 4 upheld):
#     - Practice admin: 3 received, of which 3 upheld.
#     - Medical: 3 received, of which 1 upheld.
#
# Complaints by subject (6 received, of which 4 upheld):
#     - Practice admin: 3 received, of which 3 upheld.
#     - Clinical: 3 received, of which 1 upheld.
#
# ---------------
# Complaint report for: ESPLANADE SURGERY (J84005)
#
# Address: THE ESPLANADE SURGERY, 19 THE ESPLANADE, RYDE, ISLE OF WIGHT, PO33 2EH.
# Telephone: 01983 618388
#
# Complaints by area (10 received, of which 10 upheld):
#     - Practice admin: 4 received, of which 4 upheld.
#     - Medical: 6 received, of which 6 upheld.
#
# Complaints by subject (10 received, of which 10 upheld):
#     - Practice admin: 4 received, of which 4 upheld.
#     - Clinical: 6 received, of which 6 upheld.
#
# ---------------
# Complaint report for: ARGYLL HOUSE (J84008)
#
# Address: ARGYLL HOUSE, WEST STREET, RYDE, ISLE OF WIGHT, PO33 2QG.
# Telephone: 01983 562955
#
# Complaints by area (7 received, of which 0 upheld):
#     - Medical: 3 received, of which 0 upheld.
#     - Other: 4 received, of which 0 upheld.
#
# Complaints by subject (7 received, of which 0 upheld):
#     - Other: 1 received, of which 0 upheld.
#     - Communications/Attitude: 2 received, of which 0 upheld.
#     - Clinical: 3 received, of which 0 upheld.
#     - Practice/Surgery Management: 1 received, of which 0 upheld.
#
# ---------------
# Complaint report for: SHANKLIN MEDICAL CENTRE (J84010)
#
# Address: SHANKLIN MEDICAL CENTRE, CARTER ROAD, SHANKLIN, ISLE OF WIGHT, PO37 7HR.
# Telephone: 01983 862245
#
# Complaints by area (4 received, of which 1 upheld):
#     - Medical: 4 received, of which 1 upheld.
#
# Complaints by subject (4 received, of which 1 upheld):
#     - Communications/Attitude: 2 received, of which 1 upheld.
#     - Clinical: 2 received, of which 0 upheld.
#
# ---------------
# Complaint report for: CARISBROOKE HEALTH CENTRE (J84011)
#
# Address: CARISBROOKE HEALTH CENTRE, 22 CARISBROOKE HIGH ST., CARISBROOKE, NEWPORT, ISLE OF WIGHT, PO30 1NR.
# Telephone: 01983 522150
#
# Complaints by area (21 received, of which 21 upheld):
#     - Practice admin: 7 received, of which 7 upheld.
#     - Medical: 9 received, of which 9 upheld.
#     - Other: 5 received, of which 5 upheld.
#
# Complaints by subject (21 received, of which 21 upheld):
#     - Premises: 1 received, of which 1 upheld.
#     - Practice admin: 6 received, of which 6 upheld.
#     - Communications/Attitude: 5 received, of which 5 upheld.
#     - Clinical: 9 received, of which 9 upheld.
#
# ---------------
# Complaint report for: TOWER HOUSE SURGERY (J84012)
#
# Address: TOWER HOUSE SURGERY, RINK ROAD, RYDE, ISLE OF WIGHT, PO33 1LP.
# Telephone: 01983 817200
#
# Complaints by area (10 received, of which 7 upheld):
#     - Practice admin: 3 received, of which 2 upheld.
#     - Medical: 5 received, of which 5 upheld.
#     - Other: 2 received, of which 0 upheld.
#
# Complaints by subject (10 received, of which 7 upheld):
#     - Premises: 1 received, of which 0 upheld.
#     - Practice admin: 3 received, of which 2 upheld.
#     - Communications/Attitude: 1 received, of which 0 upheld.
#     - Clinical: 5 received, of which 5 upheld.
#
# ---------------
# Complaint report for: SANDOWN HEALTH CENTRE (J84013)
#
# Address: SANDOWN HEALTH CENTRE, BROADWAY, SANDOWN, ISLE OF WIGHT, PO36 9GA.
# Telephone: 01938 409292
#
# Complaints by area (7 received, of which 4 upheld):
#     - Practice admin: 2 received, of which 2 upheld.
#     - Medical: 4 received, of which 2 upheld.
#     - Other: 1 received, of which 0 upheld.
#
# Complaints by subject (7 received, of which 4 upheld):
#     - Communications/Attitude: 6 received, of which 4 upheld.
#     - Other: 1 received, of which 0 upheld.
#
# ---------------
# Complaint report for: THE DOWER HOUSE (J84014)
#
# Address: THE DOWER HOUSE, 27 PYLE STREET, NEWPORT, ISLE OF WIGHT, PO30 1JW.
# Telephone: 01983 523525
#
# Complaints by area (28 received, of which 22 upheld):
#     - Practice admin: 11 received, of which 8 upheld.
#     - Medical: 17 received, of which 14 upheld.
#
# Complaints by subject (28 received, of which 22 upheld):
#     - Practice admin: 4 received, of which 3 upheld.
#     - Communications/Attitude: 2 received, of which 2 upheld.
#     - Clinical: 17 received, of which 14 upheld.
#     - Practice/Surgery Management: 5 received, of which 3 upheld.
#
# ---------------
# Complaint report for: COWES MEDICAL CENTRE (J84015)
#
# Address: COWES MEDICAL CENTRE, 200 NEWPORT ROAD, COWES, ISLE OF WIGHT, PO31 7ER.
# Telephone: 01983 295251
#
# Complaints by area (9 received, of which 7 upheld):
#     - Practice admin: 4 received, of which 3 upheld.
#     - Medical: 3 received, of which 3 upheld.
#     - Other: 2 received, of which 1 upheld.
#
# Complaints by subject (9 received, of which 7 upheld):
#     - Premises: 1 received, of which 1 upheld.
#     - Practice admin: 4 received, of which 3 upheld.
#     - Clinical: 3 received, of which 3 upheld.
#     - Other: 1 received, of which 0 upheld.
#
# ---------------
# Complaint report for: SOUTH WIGHT MEDICAL PRACTICE (J84016)
#
# Address: THE SURGERY, BLACKGANG ROAD, NITON, ISLE OF WIGHT, PO38 2BN.
# Telephone: 01983 740219
#
# Complaints by area (4 received, of which 1 upheld):
#     - Practice admin: 1 received, of which 1 upheld.
#     - Medical: 3 received, of which 0 upheld.
#
# Complaints by subject (4 received, of which 1 upheld):
#     - Communications/Attitude: 1 received, of which 1 upheld.
#     - Clinical: 3 received, of which 0 upheld.
#
# ---------------
# Complaint report for: MEDINA HEALTHCARE (J84017)
#
# Address: MEDINA HEALTHCARE, 16 WEST STREET, NEWPORT, ISLE OF WIGHT, PO30 1PR.
# Telephone: 01983 522198
#
# Complaints by area (6 received, of which 5 upheld):
#     - Practice admin: 4 received, of which 4 upheld.
#     - Medical: 2 received, of which 1 upheld.
#
# Complaints by subject (6 received, of which 5 upheld):
#     - Practice admin: 3 received, of which 3 upheld.
#     - Communications/Attitude: 1 received, of which 1 upheld.
#     - Clinical: 2 received, of which 1 upheld.
#
# ---------------
# Complaint report for: GROVE HOUSE SURGERY (J84018)
#
# Address: GROVE HOUSE SURGERY, 102 ALBERT STREET, VENTNOR, ISLE OF WIGHT, PO38 1EU.
# Telephone: 01983 852427
#
# Complaints by area (2 received, of which 2 upheld):
#     - Practice admin: 1 received, of which 1 upheld.
#     - Medical: 1 received, of which 1 upheld.
#
# Complaints by subject (2 received, of which 2 upheld):
#     - Communications/Attitude: 1 received, of which 1 upheld.
#     - Clinical: 1 received, of which 1 upheld.
#
# ---------------
# Complaint report for: BEECH GROVE SURGERY (J84020)
#
# Address: BEECH GROVE SURGERY, THE MALL, BRADING, ISLE OF WIGHT, PO36 0DE.
# Telephone: 01983 407558
#
# No complaints by area.
# No complaints by subject.
#
#
#
# ---------------
# Complaint report for: GARFIELD ROAD SURGERY (J84602)
#
# Address: 18 GARFIELD ROAD, RYDE, ISLE OF WIGHT, PO33 2PT.
# Telephone: 01983 565103
#
# Complaints by area (1 received, of which 0 upheld):
#     - Medical: 1 received, of which 0 upheld.
#
# Complaints by subject (1 received, of which 0 upheld):
#     - Clinical: 1 received, of which 0 upheld.

# %% [markdown]
# ## Complaints Data - 2014 / 15
#
# via: http://digital.nhs.uk/datacollections/ko41b
# specifically: http://digital.nhs.uk/searchcatalogue?productid=18408

# %%
url='http://www.hscic.gov.uk/catalogue/PUB18021/data-writ-comp-nhs-2014-2015-csv.zip'
zip_2014_15=zipgrabber(url)
complaints_2014_15=pd.read_csv(zip_2014_15.open('Data on Written Complaints in the NHS 2014-15 KO41a csv.csv'))
complaints_2014_15.dropna(how='all',axis=1,inplace=True)
complaints_2014_15.head(3)
# Out:
#       Year Area_Team_Code                          Area_Team_Name Org_Code  \
# 0  2014-15            Q45             Durham, Darlington and Tees      00C
# 1  2014-15            Q45             Durham, Darlington and Tees      00D
# 2  2014-15            Q49  Cumbria, Northumberland, Tyne and Wear      00F
#
#                                          Org_Name  \
# 0                              NHS Darlington CCG
# 1  NHS Durham Dales, Easington and Sedgefield CCG
# 2                               NHS Gateshead CCG
#
#    Hospital acute services: Inpatient total  \
# 0                                         0
# 1                                         0
# 2                                         0
#
#    Hospital acute services: Inpatient total upheld  \
# 0                                                0
# 1                                                0
# 2                                                0
#
#    Hospital acute services: Outpatient total  \
# 0                                          0
# 1                                          0
# 2                                          0
#
#    Hospital acute services: Outpatient total upheld  \
# 0                                                 0
# 1                                                 0
# 2                                                 0
#
#    Hospital acute services: A&E total       ...        \
# 0                                   0       ...
# 1                                   0       ...
# 2                                   0       ...
#
#    Policy and commercial decisions of trusts total  \
# 0                                                0
# 1                                                0
# 2                                                0
#
#    Policy and commercial decisions of trusts total upheld  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
#
#    Code of openness - complaints total  \
# 0                                    0
# 1                                    0
# 2                                    0
#
#    Code of openness - complaints total upheld  \
# 0                                           0
# 1                                           0
# 2                                           0
#
#    Hotel services (including food) total  \
# 0                                      0
# 1                                      0
# 2                                      0
#
#    Hotel services (including food) total upheld  Other total.2  \
# 0                                             0            0.0
# 1                                             0            0.0
# 2                                             0            0.0
#
#    Other total upheld.2  TOTAL.2  TOTAL upheld.2
# 0                     0        4               0
# 1                     0        3               2
# 2                     0        4               2
#
# [3 rows x 107 columns]

# %%
get_metadata(zip_2014_15)
# Out:
#                                                  Name                  typ  \
# 0                                                Year  (date time yyyy/yy)
# 1                                              Return            (varchar)
# 2                                      Area_Team_Code            (varchar)
# 3                                      Area_Team_Name            (varchar)
# 4                                       Practice_Code            (varchar)
# 5   Medical Total number of written complaints rec...                (int)
# 6   Dental Total number of written complaints rece...                (int)
# 7   Practice Admin Total number of written complai...                (int)
# 8   Other Total number of written complaints received                (int)
# 9         Total number of written complaints received                (int)
# 10  Communications/attitude Total number of writte...                (int)
# 11  Premises Total number of written complaints re...                (int)
# 12  Practice/surgery management Total number of wr...                (int)
# 13  Practice administration Total number of writte...                (int)
# 14  Clinical Total number of written complaints re...                (int)
# 15  Other Total number of written complaints received                (int)
# 16        Total number of written complaints received                (int)
# 17  Medical Total number of written \ncomplaints u...                (int)
# 18  Dental Total number of written \ncomplaints up...                (int)
# 19  Practice Admin Total number of written \ncompl...                (int)
# 20  Other Total number of written \ncomplaints upheld                (int)
# 21        Total number of written \ncomplaints upheld                (int)
# 22  Communications/attitude Total number of writte...                (int)
# 23  Premises Total number of written \ncomplaints ...                (int)
# 24  Practice/surgery management Total number of wr...                (int)
# 25  Practice administration Total number of writte...                (int)
# 26  Clinical Total number of written \ncomplaints ...                (int)
# 27  Other Total number of written \ncomplaints upheld                (int)
# 28        Total number of written \ncomplaints upheld                (int)
#
#                                                  meta
# 0                                  Year of collection
# 1   Organisation type (Area Team, GP practice, Den...
# 2                          NHS England Area Team Code
# 3                          NHS England Area Team Name
# 4                             Dental/GP Practice Code
# 5                                   Complaint by area
# 6                                   Complaint by area
# 7                                   Complaint by area
# 8                                   Complaint by area
# 9                                   Complaint by area
# 10                               Complaint by subject
# 11                               Complaint by subject
# 12                               Complaint by subject
# 13                               Complaint by subject
# 14                               Complaint by subject
# 15                               Complaint by subject
# 16                               Complaint by subject
# 17                                  Complaint by area
# 18                                  Complaint by area
# 19                                  Complaint by area
# 20                                  Complaint by area
# 21                                  Complaint by area
# 22                               Complaint by subject
# 23                               Complaint by subject
# 24                               Complaint by subject
# 25                               Complaint by subject
# 26                               Complaint by subject
# 27                               Complaint by subject
# 28                               Complaint by subject

# %%
complaints_b_2014_15=csvfileopener(zip_2014_15,'KO41b',True)
complaints_b_2014_15.head(3)
# Out:
#   Year::Year of collection  \
# 0                  2014-15
# 1                  2014-15
# 2                  2014-15
#
#   Return::Organisation type (Area Team, GP practice, Dental practice) making return  \
# 0                                             Dental
# 1                                             Dental
# 2                                             Dental
#
#   Area_Team_Code::NHS England Area Team Code  \
# 0                                        Q44
# 1                                        Q44
# 2                                        Q44
#
#   Area_Team_Name::NHS England Area Team Name  \
# 0            Cheshire, Warrington and Wirral
# 1            Cheshire, Warrington and Wirral
# 2            Cheshire, Warrington and Wirral
#
#   Practice_Code::Dental/GP Practice Code  \
# 0                                 V01008
# 1                                 V03463
# 2                                 V04661
#
#    Medical Total number of written complaints received::Complaint by area  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
#
#    Dental Total number of written complaints received::Complaint by area  \
# 0                                                  0
# 1                                                  1
# 2                                                  1
#
#    Practice Admin Total number of written complaints received::Complaint by area  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
#
#    Other Total number of written complaints received::Complaint by area  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
#
#    Total number of written complaints received::Complaint by area  \
# 0                                                  0
# 1                                                  1
# 2                                                  1
#
#                                  ...                                  \
# 0                                ...
# 1                                ...
# 2                                ...
#
#    Practice Admin Total number of written \ncomplaints upheld::Complaint by area  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
#
#    Other Total number of written \ncomplaints upheld::Complaint by area  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
#
#    Total number of written \ncomplaints upheld::Complaint by area  \
# 0                                                  0
# 1                                                  1
# 2                                                  0
#
#    Communications/attitude Total number of written \ncomplaints upheld::Complaint by subject  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
#
#    Premises Total number of written \ncomplaints upheld::Complaint by subject  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
#
#    Practice/surgery management Total number of written \ncomplaints upheld::Complaint by subject  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
#
#    Practice administration Total number of written \ncomplaints upheld::Complaint by subject  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
#
#    Clinical Total number of written \ncomplaints upheld::Complaint by subject  \
# 0                                                  0
# 1                                                  1
# 2                                                  0
#
#    Other Total number of written \ncomplaints upheld::Complaint by subject  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
#
#    Total number of written \ncomplaints upheld::Complaint by subject
# 0                                                  0
# 1                                                  1
# 2                                                  0
#
# [3 rows x 29 columns]

# %%
#join complaints parent codes
parentGP=gp[['Organisation Code','Commissioner']]
parentGP.columns=['Organisation Code','Parent Organisation Code']
parentDentist=dentists[['Organisation Code','Parent Organisation Code']]
codeparent=pd.concat([parentGP,parentDentist])
codeparent.head(3)
# Out:
#   Organisation Code Parent Organisation Code
# 0            A81001                      00K
# 1            A81002                      00K
# 2            A81003                      00K

# %%
iwcodes=codeparent[(codeparent['Parent Organisation Code']=='10L')]
complaints_iw=pd.merge(complaints_b_2014_15,iwcodes, left_on='Practice_Code::Dental/GP Practice Code', right_on='Organisation Code')
gp[gp['Organisation Code'].isin(complaints_iw['Practice_Code::Dental/GP Practice Code'].tolist())].head()
# Out:
#      Organisation Code                       Name National Grouping  \
# 5255            J84003     VENTNOR MEDICAL CENTRE               Y57
# 5256            J84004  EAST COWES MEDICAL CENTRE               Y57
# 5257            J84005          ESPLANADE SURGERY               Y57
# 5258            J84007   ST.HELENS MEDICAL CENTRE               Y57
# 5259            J84008               ARGYLL HOUSE               Y57
#
#      High Level Health Geography             Address Line 1    Address Line 2  \
# 5255                         Q70     VENTNOR MEDICAL CENTRE   3 ALBERT STREET
# 5256                         Q70  EAST COWES MEDICAL CENTRE       CHURCH PATH
# 5257                         Q70      THE ESPLANADE SURGERY  19 THE ESPLANADE
# 5258                         Q70   ST.HELENS MEDICAL CENTRE  UPPER GREEN ROAD
# 5259                         Q70               ARGYLL HOUSE       WEST STREET
#
#      Address Line 3 Address Line 4 Address Line 5  Postcode  \
# 5255        VENTNOR  ISLE OF WIGHT           None  PO38 1EZ
# 5256     EAST COWES  ISLE OF WIGHT           None  PO32 6RP
# 5257           RYDE  ISLE OF WIGHT           None  PO33 2EH
# 5258      ST.HELENS  ISLE OF WIGHT           None  PO33 1UG
# 5259           RYDE  ISLE OF WIGHT           None  PO33 2QG
#
#              ...         Close Date Status Code Organisation Sub-Type code  \
# 5255         ...               None           A                          B
# 5256         ...               None           A                          B
# 5257         ...               None           A                          B
# 5258         ...               None           A                          B
# 5259         ...               None           A                          B
#
#      Commissioner Join Provider/Purchaser Date Left Provider/Purchaser Date  \
# 5255          10L          2013-04-01 00:00:00                         None
# 5256          10L          2013-04-01 00:00:00                         None
# 5257          10L          2013-04-01 00:00:00                         None
# 5258          10L          2013-04-01 00:00:00                         None
# 5259          10L          2013-04-01 00:00:00                         None
#
#      Contact Telephone Number Amended Record Indicator  Provider/Purchaser  \
# 5255             01983 857288                        0                 10L
# 5256             01983 284333                        0                 10L
# 5257             01983 618388                        0                 10L
# 5258             01983 871828                        0                 10L
# 5259             01983 562955                        0                 10L
#
#      Prescribing Setting
# 5255                   4
# 5256                   4
# 5257                   4
# 5258                   4
# 5259                   4
#
# [5 rows x 21 columns]

# %%
reports=complaints_iw.apply(lambda x: complaintReport(x,hack2014=True), axis=1 )

print('''
National Statistics Data on Written Complaints in the NHS - 2014-15 [NS]
Publication date: ??, 2015
http://www.digital.nhs.uk/catalogue/PUB21533
''')

for report in reports:
    print(report)
# Out:
# National Statistics Data on Written Complaints in the NHS - 2014-15 [NS]
# Publication date: ??, 2015
# http://www.digital.nhs.uk/catalogue/PUB21533
#
#
# ---------------
# Complaint report for: VENTNOR MEDICAL CENTRE (J84003)
#
# Address: VENTNOR MEDICAL CENTRE, 3 ALBERT STREET, VENTNOR, ISLE OF WIGHT, PO38 1EZ.
# Telephone: 01983 857288
#
# Complaints by area (1 received, of which 0 upheld):
#     - Practice Admin: 1 received, of which 0 upheld.
#
# Complaints by subject (3 received, of which 0 upheld):
#     - Clinical: 1 received, of which 0 upheld.
#     - Communications/attitude: 1 received, of which 0 upheld.
#     - Practice administration: 1 received, of which 0 upheld.
#
# ---------------
# Complaint report for: EAST COWES MEDICAL CENTRE (J84004)
#
# Address: EAST COWES MEDICAL CENTRE, CHURCH PATH, EAST COWES, ISLE OF WIGHT, PO32 6RP.
# Telephone: 01983 284333
#
# Complaints by area (11 received, of which 11 upheld):
#     - Practice Admin: 6 received, of which 6 upheld.
#     - Medical: 4 received, of which 4 upheld.
#     - Other: 1 received, of which 1 upheld.
#
# Complaints by subject (11 received, of which 11 upheld):
#     - Premises: 1 received, of which 1 upheld.
#     - Clinical: 3 received, of which 3 upheld.
#     - Communications/attitude: 4 received, of which 4 upheld.
#     - Practice administration: 3 received, of which 3 upheld.
#
# ---------------
# Complaint report for: ESPLANADE SURGERY (J84005)
#
# Address: THE ESPLANADE SURGERY, 19 THE ESPLANADE, RYDE, ISLE OF WIGHT, PO33 2EH.
# Telephone: 01983 618388
#
# Complaints by area (6 received, of which 5 upheld):
#     - Practice Admin: 2 received, of which 2 upheld.
#     - Medical: 3 received, of which 2 upheld.
#     - Other: 1 received, of which 1 upheld.
#
# Complaints by subject (6 received, of which 5 upheld):
#     - Other: 2 received, of which 1 upheld.
#     - Clinical: 1 received, of which 1 upheld.
#     - Communications/attitude: 2 received, of which 2 upheld.
#     - Practice administration: 1 received, of which 1 upheld.
#
# ---------------
# Complaint report for: ST.HELENS MEDICAL CENTRE (J84007)
#
# Address: ST.HELENS MEDICAL CENTRE, UPPER GREEN ROAD, ST.HELENS, ISLE OF WIGHT, PO33 1UG.
# Telephone: 01983 871828
#
# Complaints by area (12 received, of which 10 upheld):
#     - Other: 12 received, of which 10 upheld.
#
# Complaints by subject (12 received, of which 10 upheld):
#     - Communications/attitude: 2 received, of which 2 upheld.
#     - Practice administration: 3 received, of which 3 upheld.
#     - Practice/surgery management: 1 received, of which 1 upheld.
#     - Other: 1 received, of which 0 upheld.
#     - Clinical: 5 received, of which 4 upheld.
#
# ---------------
# Complaint report for: ARGYLL HOUSE (J84008)
#
# Address: ARGYLL HOUSE, WEST STREET, RYDE, ISLE OF WIGHT, PO33 2QG.
# Telephone: 01983 562955
#
# Complaints by area (4 received, of which 0 upheld):
#     - Medical: 3 received, of which 0 upheld.
#     - Other: 1 received, of which 0 upheld.
#
# Complaints by subject (4 received, of which 0 upheld):
#     - Communications/attitude: 1 received, of which 0 upheld.
#     - Clinical: 3 received, of which 0 upheld.
#
# ---------------
# Complaint report for: SHANKLIN MEDICAL CENTRE (J84010)
#
# Address: SHANKLIN MEDICAL CENTRE, CARTER ROAD, SHANKLIN, ISLE OF WIGHT, PO37 7HR.
# Telephone: 01983 862245
#
# Complaints by area (8 received, of which 2 upheld):
#     - Medical: 8 received, of which 2 upheld.
#
# Complaints by subject (8 received, of which 2 upheld):
#     - Communications/attitude: 7 received, of which 1 upheld.
#     - Clinical: 1 received, of which 1 upheld.
#
# ---------------
# Complaint report for: CARISBROOKE HEALTH CENTRE (J84011)
#
# Address: CARISBROOKE HEALTH CENTRE, 22 CARISBROOKE HIGH ST., CARISBROOKE, NEWPORT, ISLE OF WIGHT, PO30 1NR.
# Telephone: 01983 522150
#
# Complaints by area (9 received, of which 9 upheld):
#     - Practice Admin: 3 received, of which 3 upheld.
#     - Medical: 2 received, of which 2 upheld.
#     - Other: 4 received, of which 4 upheld.
#
# Complaints by subject (9 received, of which 9 upheld):
#     - Communications/attitude: 3 received, of which 3 upheld.
#     - Premises: 1 received, of which 1 upheld.
#     - Practice administration: 1 received, of which 1 upheld.
#     - Clinical: 3 received, of which 3 upheld.
#     - Other: 1 received, of which 1 upheld.
#
# ---------------
# Complaint report for: TOWER HOUSE SURGERY (J84012)
#
# Address: TOWER HOUSE SURGERY, RINK ROAD, RYDE, ISLE OF WIGHT, PO33 1LP.
# Telephone: 01983 817200
#
# Complaints by area (8 received, of which 1 upheld):
#     - Practice Admin: 1 received, of which 1 upheld.
#     - Medical: 7 received, of which 0 upheld.
#
# Complaints by subject (8 received, of which 1 upheld):
#     - Clinical: 5 received, of which 0 upheld.
#     - Communications/attitude: 2 received, of which 0 upheld.
#     - Practice administration: 1 received, of which 1 upheld.
#
# ---------------
# Complaint report for: SANDOWN HEALTH CENTRE (J84013)
#
# Address: SANDOWN HEALTH CENTRE, BROADWAY, SANDOWN, ISLE OF WIGHT, PO36 9GA.
# Telephone: 01938 409292
#
# Complaints by area (10 received, of which 5 upheld):
#     - Practice Admin: 3 received, of which 1 upheld.
#     - Medical: 6 received, of which 4 upheld.
#     - Other: 1 received, of which 0 upheld.
#
# Complaints by subject (10 received, of which 5 upheld):
#     - Clinical: 3 received, of which 0 upheld.
#     - Communications/attitude: 6 received, of which 4 upheld.
#     - Practice administration: 1 received, of which 1 upheld.
#
# ---------------
# Complaint report for: THE DOWER HOUSE (J84014)
#
# Address: THE DOWER HOUSE, 27 PYLE STREET, NEWPORT, ISLE OF WIGHT, PO30 1JW.
# Telephone: 01983 523525
#
# Complaints by area (11 received, of which 11 upheld):
#     - Practice Admin: 2 received, of which 2 upheld.
#     - Medical: 9 received, of which 9 upheld.
#
# Complaints by subject (11 received, of which 11 upheld):
#     - Other: 0 received, of which 9 upheld.
#     - Clinical: 9 received, of which 0 upheld.
#     - Practice administration: 2 received, of which 2 upheld.
#
# ---------------
# Complaint report for: COWES MEDICAL CENTRE (J84015)
#
# Address: COWES MEDICAL CENTRE, 200 NEWPORT ROAD, COWES, ISLE OF WIGHT, PO31 7ER.
# Telephone: 01983 295251
#
# Complaints by area (10 received, of which 4 upheld):
#     - Practice Admin: 2 received, of which 2 upheld.
#     - Medical: 8 received, of which 2 upheld.
#
# Complaints by subject (10 received, of which 4 upheld):
#     - Clinical: 8 received, of which 2 upheld.
#     - Practice administration: 2 received, of which 2 upheld.
#
# ---------------
# Complaint report for: SOUTH WIGHT MEDICAL PRACTICE (J84016)
#
# Address: THE SURGERY, BLACKGANG ROAD, NITON, ISLE OF WIGHT, PO38 2BN.
# Telephone: 01983 740219
#
# Complaints by area (9 received, of which 0 upheld):
#     - Medical: 7 received, of which 0 upheld.
#     - Other: 2 received, of which 0 upheld.
#
# Complaints by subject (9 received, of which 0 upheld):
#     - Communications/attitude: 2 received, of which 0 upheld.
#     - Clinical: 7 received, of which 0 upheld.
#
# ---------------
# Complaint report for: MEDINA HEALTHCARE (J84017)
#
# Address: MEDINA HEALTHCARE, 16 WEST STREET, NEWPORT, ISLE OF WIGHT, PO30 1PR.
# Telephone: 01983 522198
#
# Complaints by area (7 received, of which 7 upheld):
#     - Practice Admin: 2 received, of which 2 upheld.
#     - Medical: 5 received, of which 5 upheld.
#
# Complaints by subject (7 received, of which 7 upheld):
#     - Clinical: 4 received, of which 4 upheld.
#     - Practice administration: 2 received, of which 2 upheld.
#     - Practice/surgery management: 1 received, of which 1 upheld.
#
# ---------------
# Complaint report for: GROVE HOUSE SURGERY (J84018)
#
# Address: GROVE HOUSE SURGERY, 102 ALBERT STREET, VENTNOR, ISLE OF WIGHT, PO38 1EU.
# Telephone: 01983 852427
#
# Complaints by area (6 received, of which 3 upheld):
#     - Practice Admin: 3 received, of which 3 upheld.
#     - Medical: 3 received, of which 0 upheld.
#
# Complaints by subject (6 received, of which 3 upheld):
#     - Clinical: 3 received, of which 0 upheld.
#     - Practice administration: 3 received, of which 3 upheld.
#
# ---------------
# Complaint report for: WEST WIGHT MEDICAL PRACTICE (J84019)
#
# Address: BROOKSIDE HEALTH CENTRE, QUEENS ROAD, FRESHWATER, ISLE OF WIGHT, PO40 9DT.
# Telephone: 01983 758998
#
# Complaints by area (10 received, of which 0 upheld):
#     - Other: 10 received, of which 0 upheld.
#
# Complaints by subject (10 received, of which 0 upheld):
#     - Clinical: 3 received, of which 0 upheld.
#     - Communications/attitude: 4 received, of which 0 upheld.
#     - Practice administration: 3 received, of which 0 upheld.
#
# ---------------
# Complaint report for: BEECH GROVE SURGERY (J84020)
#
# Address: BEECH GROVE SURGERY, THE MALL, BRADING, ISLE OF WIGHT, PO36 0DE.
# Telephone: 01983 407558
#
# Complaints by area (2 received, of which 1 upheld):
#     - Practice Admin: 2 received, of which 1 upheld.
#
# Complaints by subject (2 received, of which 1 upheld):
#     - Practice administration: 2 received, of which 1 upheld.
#
# ---------------
# Complaint report for: GARFIELD ROAD SURGERY (J84602)
#
# Address: 18 GARFIELD ROAD, RYDE, ISLE OF WIGHT, PO33 2PT.
# Telephone: 01983 565103
#
# Complaints by area (3 received, of which 2 upheld):
#     - Practice Admin: 1 received, of which 1 upheld.
#     - Medical: 1 received, of which 0 upheld.
#     - Other: 1 received, of which 1 upheld.
#
# Complaints by subject (3 received, of which 2 upheld):
#     - Clinical: 1 received, of which 0 upheld.
#     - Communications/attitude: 1 received, of which 1 upheld.
#     - Practice administration: 1 received, of which 1 upheld.
